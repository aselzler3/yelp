# %%
import numpy as np
import pandas as pd
import json

# %%
minidata=[]
data=[]

# %%
with open('data/minireview.json',encoding='utf-8') as f:
    for line in f:
        minidata.append(json.loads(line))

# %%
minidata
# Out:
# [{'business_id': '0W4lkclzZThpx3V65bVgig',
#   'cool': 0,
#   'date': '2016-05-28',
#   'funny': 0,
#   'review_id': 'v0i_UHJMo_hPBq9bxWvW4w',
#   'stars': 5,
#   'text': "Love the staff, love the meat, love the place. Prepare for a long line around lunch or dinner hours. \n\nThey ask you how you want you meat, lean or something maybe, I can't remember. Just say you don't want it too fatty. \n\nGet a half sour pickle and a hot pepper. Hand cut french fries too.",
#   'useful': 0,
#   'user_id': 'bv2nCi5Qv5vroFiqKGopiw'},
#  {'business_id': 'AEx2SYEUJmTxVVB18LlCwA',
#   'cool': 0,
#   'date': '2016-05-28',
#   'funny': 0,
#   'review_id': 'vkVSCC7xljjrAI4UGfnKEQ',
#   'stars': 5,
#   'text': "Super simple place but amazing nonetheless. It's been around since the 30's and they still serve the same thing they started with: a bologna and salami sandwich with mustard. \n\nStaff was very helpful and friendly.",
#   'useful': 0,
#   'user_id': 'bv2nCi5Qv5vroFiqKGopiw'},
# ...

# %%
with open('data/review.json',encoding='utf-8') as F:
    for line in F:
        data.append(json.loads(line))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-7-1384756b1c68> in <module>()
#       1 with open('data/review.json',encoding='utf-8') as F:
#       2     for line in F:
# ----> 3         data.append(json.loads(line))
#
# ~/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
# ...

# %%
data[-1]
# Out:
# {'business_id': '4P9xEvV7r5Op0Ui7OaUcSw',
#  'cool': 0,
#  'date': '2015-08-27',
#  'funny': 0,
#  'review_id': '57YeXG6VRLIrZdsBdc1NBA',
#  'stars': 5,
#  'text': 'This is an awesome Christian based child day care. Our two boys have been going there for almost three years now and our oldest just graduated. Highly recomend.',
#  'useful': 2,
#  'user_id': 'M8Zwemrid0sLPsJMfrIBNQ'}

# %%
len(data)
# Out:
# 134082

# %%
mini_data=pd.read_json('data/minireview.json',encoding='utf-8',lines=True)

# %%
mini_data
# Out:
#                business_id  cool       date  funny               review_id  \
# 0   0W4lkclzZThpx3V65bVgig     0 2016-05-28      0  v0i_UHJMo_hPBq9bxWvW4w
# 1   AEx2SYEUJmTxVVB18LlCwA     0 2016-05-28      0  vkVSCC7xljjrAI4UGfnKEQ
# 2   VR6GpWIda3SfvPC-lg9H3w     0 2016-05-28      0  n6QzIUObkYshz4dz2QRJTw
# 3   CKC0-MOWMqoeWf6s-szl8g     0 2016-05-28      0  MV3CcKScW05u5LVfF6ok0g
# 4   ACFtxLv8pGrrxMm6EgjreA     0 2016-05-28      0  IXvOzsEMYtiJI0CARmj77Q
# 5   s2I_Ni76bjJNK9yG60iD-Q     0 2016-05-28      0  L_9BTb55X0GDtThi6GlZ6w
# 6   8QWPlVQ6D-OExqXoaD2Z1g     0 2014-09-24      0  HRPm3vEZ_F-33TYVT7Pebw
# 7   9_CGhHMz8698M9-PkVf0CQ     2 2012-05-11      0  ymAUG8DZfQcFTBSOiaNN4w
# 8   gkCorLgPyQLsptTHalL61g     0 2015-10-27      0  8UIishPUD92hXtScSga_gw
# 9   5r6-G9C4YLbC7Ziz57l3rQ     0 2013-02-09      0  w41ZS9shepfO3uEyhXEWuQ
# 10  fDF_o2JPU8BR1Gya--jRIA     0 2016-04-06      0  WF_QTN3p-thD74hqpp2j-Q
# ...

# %%
data=pd.read_json('data/review.json', encoding='utf-8', lines=True)

# %%
data.head(20)
# Out:
#                business_id  cool       date  funny               review_id  \
# 0   0W4lkclzZThpx3V65bVgig     0 2016-05-28      0  v0i_UHJMo_hPBq9bxWvW4w
# 1   AEx2SYEUJmTxVVB18LlCwA     0 2016-05-28      0  vkVSCC7xljjrAI4UGfnKEQ
# 2   VR6GpWIda3SfvPC-lg9H3w     0 2016-05-28      0  n6QzIUObkYshz4dz2QRJTw
# 3   CKC0-MOWMqoeWf6s-szl8g     0 2016-05-28      0  MV3CcKScW05u5LVfF6ok0g
# 4   ACFtxLv8pGrrxMm6EgjreA     0 2016-05-28      0  IXvOzsEMYtiJI0CARmj77Q
# 5   s2I_Ni76bjJNK9yG60iD-Q     0 2016-05-28      0  L_9BTb55X0GDtThi6GlZ6w
# 6   8QWPlVQ6D-OExqXoaD2Z1g     0 2014-09-24      0  HRPm3vEZ_F-33TYVT7Pebw
# 7   9_CGhHMz8698M9-PkVf0CQ     2 2012-05-11      0  ymAUG8DZfQcFTBSOiaNN4w
# 8   gkCorLgPyQLsptTHalL61g     0 2015-10-27      0  8UIishPUD92hXtScSga_gw
# 9   5r6-G9C4YLbC7Ziz57l3rQ     0 2013-02-09      0  w41ZS9shepfO3uEyhXEWuQ
# 10  fDF_o2JPU8BR1Gya--jRIA     0 2016-04-06      0  WF_QTN3p-thD74hqpp2j-Q
# ...

# %%
len(data)
# Out:
# 134082
